# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Df_Acc_copie_M.csv")
#df = df.drop(["Unnamed:0"], axis = 1)
df.head()
# Out:
#          catu  grav  sexe               trajet  Age                  catr  \
# 0  Conducteur     4     0   Domicile – travail   24  Route departementale
# 1  Conducteur     4     1                Autre   12  Route departementale
# 2  Conducteur     1     1  Promenade – loisirs   86  Route departementale
# 3    Passager     4     0  Promenade – loisirs   85        Voie comunales
# 4  Conducteur     4     1  Promenade – loisirs   33       Route nationale
#
#                    circ        vosp  prof                plan  ...  \
# 0      Bidirectionnelle  Sans objet  Plat   Partie Rectiligne  ...
# 1      Bidirectionnelle  Sans objet  Plat  En courbe à droite  ...
# 2  A chaussées séparées  Sans objet  Plat   Partie Rectiligne  ...
# 3      Bidirectionnelle  Sans objet  Plat   Partie Rectiligne  ...
# 4         A sens unique  Sans objet  Plat   Partie Rectiligne  ...
#
#                infra          situ vma  mois         lum dep  \
# ...

# %%
df["grav"] = df["grav"].replace([1, 2, 3, 4], ['Indemne', 'Deceder', 'Blessé_hospitalisé', 'Blessé_leger'])

# %%
df.head()
# Out:
#          catu          grav  sexe               trajet  Age  \
# 0  Conducteur  Blessé_leger     0   Domicile – travail   24
# 1  Conducteur  Blessé_leger     1                Autre   12
# 2  Conducteur       Indemne     1  Promenade – loisirs   86
# 3    Passager  Blessé_leger     0  Promenade – loisirs   85
# 4  Conducteur  Blessé_leger     1  Promenade – loisirs   33
#
#                    catr                  circ        vosp  prof  \
# 0  Route departementale      Bidirectionnelle  Sans objet  Plat
# 1  Route departementale      Bidirectionnelle  Sans objet  Plat
# 2  Route departementale  A chaussées séparées  Sans objet  Plat
# 3        Voie comunales      Bidirectionnelle  Sans objet  Plat
# 4       Route nationale         A sens unique  Sans objet  Plat
#
#                  plan  ...              infra          situ vma  mois  \
# 0   Partie Rectiligne  ...              Aucun  Sur chaussée  50    12
# 1  En courbe à droite  ...             Autres  Sur chaussée  50    10
# ...

# %%
df.to_csv("Df_Acc_copie_F.csv", index = False)

# %%
df_12 = pd.read_csv("Df_Acc_copie_F.csv")
df_12
# Out:
#              catu          grav  sexe               trajet  Age  \
# 0      Conducteur  Blessé_leger     0   Domicile – travail   24
# 1      Conducteur  Blessé_leger     1                Autre   12
# 2      Conducteur       Indemne     1  Promenade – loisirs   86
# 3        Passager  Blessé_leger     0  Promenade – loisirs   85
# 4      Conducteur  Blessé_leger     1  Promenade – loisirs   33
# ...           ...           ...   ...                  ...  ...
# 10793  Conducteur       Indemne     1                Autre   42
# 10794  Conducteur       Indemne     1                Autre   40
# 10795  Conducteur       Indemne     1   Domicile – travail   52
# 10796      Pieton  Blessé_leger     0  Promenade – loisirs   88
# 10797  Conducteur       Indemne     1                Autre   53
#
#                        catr                  circ        vosp  prof  \
# 0      Route departementale      Bidirectionnelle  Sans objet  Plat
# ...

# %%
df_12["lum"].value_counts()
# Out:
# Plein_jour                          7364
# Nuit avec eclairage public allum    2032
# Nuit sans eclairage public           796
# Aube                                 606
# Name: lum, dtype: int64
